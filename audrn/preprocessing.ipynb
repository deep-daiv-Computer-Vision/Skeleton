# %%
import cv2
import os

# %%
def split_video(input_video, output_folder, frames_per_split=2000):
    # Open the video file
    video = cv2.VideoCapture(input_video)
    if not video.isOpened():
        print(f"Error: Could not open video '{input_video}'")
        return
    
    # Get some properties from the video file
    total_frames = int(video.get(cv2.CAP_PROP_FRAME_COUNT))
    fps = video.get(cv2.CAP_PROP_FPS)
    width = int(video.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(video.get(cv2.CAP_PROP_FRAME_HEIGHT))
    
    # Calculate number of splits needed
    num_splits = total_frames // frames_per_split
    if total_frames % frames_per_split != 0:
        num_splits += 1
    
    print(f"Total frames: {total_frames}, FPS: {fps}, Resolution: {width}x{height}")
    print(f"Splitting video into {num_splits} parts...")
    
    # Create output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    # Read and save frames
    frame_count = 0
    split_count = 0
    while True:
        success, frame = video.read()
        
        if not success:
            break
        
        # Save the frame
        if frame_count % frames_per_split == 0:
            split_count += 1
            output_filename = os.path.join(output_folder, f"part_{split_count}.mp4")
            print(f"Saving {output_filename}...")
            # Define the codec and create VideoWriter object
            fourcc = cv2.VideoWriter_fourcc(*'XVID')
            out = cv2.VideoWriter(output_filename, fourcc, fps, (width, height))
        
        out.write(frame)
        frame_count += 1
        
        # Break the loop if we have reached the desired number of frames
        if frame_count >= total_frames or split_count >= num_splits:
            break
    
    # Release everything when finished
    video.release()
    out.release()
    cv2.destroyAllWindows()
    
    print("Video splitting completed.")

# %%
# Example usage:
input_video = 'data/input_video.mp4'  # Replace with your video file path
output_folder = 'output_frames'  # Replace with your desired output folder

split_video(input_video, output_folder)
# Out:
# Total frames: 5092, FPS: 24.0, Resolution: 1280x720
# Splitting video into 3 parts...
# Saving output_frames/part_1.mp4...
# OpenCV: FFMPEG: tag 0x44495658/'XVID' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# Saving output_frames/part_2.mp4...
# OpenCV: FFMPEG: tag 0x44495658/'XVID' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# Saving output_frames/part_3.mp4...
# Video splitting completed.
# OpenCV: FFMPEG: tag 0x44495658/'XVID' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'

# %%
from ultralytics import YOLO

dir = os.getcwd()
video_path = os.path.join(dir, 'output_frames/part_1.mp4')
bytetrack_yaml_path = os.path.join(dir, 'bytetrack.yaml')

model = YOLO('yolov8n.pt')

results = model.track(source=video_path, persist=True, tracker=bytetrack_yaml_path)

results
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/2000) /home/mg/projects/deepdaiv/skeleton/audrn/output_frames/part_1.mp4: 384x640 4 persons, 141.7ms
# video 1/1 (frame 2/2000) /home/mg/projects/deepdaiv/skeleton/audrn/output_frames/part_1.mp4: 384x640 4 persons, 90.9ms
# video 1/1 (frame 3/2000) /home/mg/projects/deepdaiv/skeleton/audrn/output_frames/part_1.mp4: 384x640 4 persons, 115.2ms
# video 1/1 (frame 4/2000) /home/mg/projects/deepdaiv/skeleton/audrn/output_frames/part_1.mp4: 384x640 3 persons, 144.1ms
# video 1/1 (frame 5/2000) /home/mg/projects/deepdaiv/skeleton/audrn/output_frames/part_1.mp4: 384x640 3 persons, 109.8ms
# video 1/1 (frame 6/2000) /home/mg/projects/deepdaiv/skeleton/audrn/output_frames/part_1.mp4: 384x640 3 persons, 124.5ms
# video 1/1 (frame 7/2000) /home/mg/projects/deepdaiv/skeleton/audrn/output_frames/part_1.mp4: 384x640 3 persons, 94.7ms
# video 1/1 (frame 8/2000) /home/mg/projects/deepdaiv/skeleton/audrn/output_frames/part_1.mp4: 384x640 3 persons, 98.0ms
# video 1/1 (frame 9/2000) /home/mg/projects/deepdaiv/skeleton/audrn/output_frames/part_1.mp4: 384x640 1 person, 98.1ms
# video 1/1 (frame 10/2000) /home/mg/projects/deepdaiv/skeleton/audrn/output_frames/part_1.mp4: 384x640 1 person, 100.4ms
# video 1/1 (frame 11/2000) /home/mg/projects/deepdaiv/skeleton/audrn/output_frames/part_1.mp4: 384x640 1 person, 100.0ms
# video 1/1 (frame 12/2000) /home/mg/projects/deepdaiv/skeleton/audrn/output_frames/part_1.mp4: 384x640 1 person, 110.5ms
# video 1/1 (frame 13/2000) /home/mg/projects/deepdaiv/skeleton/audrn/output_frames/part_1.mp4: 384x640 1 person, 87.9ms
# video 1/1 (frame 14/2000) /home/mg/projects/deepdaiv/skeleton/audrn/output_frames/part_1.mp4: 384x640 1 person, 85.9ms
# video 1/1 (frame 15/2000) /home/mg/projects/deepdaiv/skeleton/audrn/output_frames/part_1.mp4: 384x640 1 person, 89.1ms
# video 1/1 (frame 16/2000) /home/mg/projects/deepdaiv/skeleton/audrn/output_frames/part_1.mp4: 384x640 2 persons, 88.6ms
# video 1/1 (frame 17/2000) /home/mg/projects/deepdaiv/skeleton/audrn/output_frames/part_1.mp4: 384x640 2 persons, 95.7ms
# video 1/1 (frame 18/2000) /home/mg/projects/deepdaiv/skeleton/audrn/output_frames/part_1.mp4: 384x640 3 persons, 88.2ms
# video 1/1 (frame 19/2000) /home/mg/projects/deepdaiv/skeleton/audrn/output_frames/part_1.mp4: 384x640 3 persons, 90.6ms
# video 1/1 (frame 20/2000) /home/mg/projects/deepdaiv/skeleton/audrn/output_frames/part_1.mp4: 384x640 4 persons, 115.1ms
# video 1/1 (frame 21/2000) /home/mg/projects/deepdaiv/skeleton/audrn/output_frames/part_1.mp4: 384x640 3 persons, 98.8ms
# video 1/1 (frame 22/2000) /home/mg/projects/deepdaiv/skeleton/audrn/output_frames/part_1.mp4: 384x640 4 persons, 83.1ms
# video 1/1 (frame 23/2000) /home/mg/projects/deepdaiv/skeleton/audrn/output_frames/part_1.mp4: 384x640 4 persons, 83.9ms
# video 1/1 (frame 24/2000) /home/mg/projects/deepdaiv/skeleton/audrn/output_frames/part_1.mp4: 384x640 3 persons, 93.5ms
# video 1/1 (frame 25/2000) /home/mg/projects/deepdaiv/skeleton/audrn/output_frames/part_1.mp4: 384x640 4 persons, 86.7ms
# video 1/1 (frame 26/2000) /home/mg/projects/deepdaiv/skeleton/audrn/output_frames/part_1.mp4: 384x640 6 persons,
2000) /home/mg/projects/deepdaiv/skeleton/audrn/output_frames/part_1.mp4: 384x640 5 persons, 98.5ms
# video 1/1 (frame 370/2000) /home/mg/projects/deepdaiv/skeleton/audrn/output_frames/part_1.mp4: 384x640 5 persons, 106.3ms
# video 1/1 (frame 371/2000) /home/mg/projects/deepdaiv/skeleton/audrn/output_frames/part_1.mp4: 384x640 5 persons, 117.4ms
# video 1/1 (frame 372/2000) /home/mg/projects/deepdaiv/skeleton/audrn/output_frames/part_1.mp4: 384x640 5 persons, 104.4ms
# video 1/1 (frame 373/2000) /home/mg/projects/deepdaiv/skeleton/audrn/output_frames/part_1.mp4: 384x640 5 persons, 108.9ms
# video 1/1 (frame 374/2000) /home/mg/projects/deepdaiv/skeleton/audrn/output_frames/part_1.mp4: 384x640 4 persons, 1 bench, 112.4ms
# video 1/1 (frame 375/2000) /home/mg/projects/deepdaiv/skeleton/audrn/output_frames/part_1.mp4: 384x640 5 persons, 110.6ms
# video 1/1 (frame 376/2000) /home/mg/projects/deepdaiv/skeleton/audrn/output_frames/part_1.mp4: 384x640 5 persons, 108.6ms
# video 1/1 (frame 377/2000) /home/mg/projects/deepdaiv/skeleton/audrn/output_frames/part_1.mp4: 384x640 5 persons, 110.4ms
# video 1/1 (frame 378/2000) /home/mg/projects/deepdaiv/skeleton/audrn/output_frames/part_1.mp4: 384x640 6 persons, 116.0ms
# video 1/1 (frame 379/2000) /home/mg/projects/deepdaiv/skeleton/audrn/output_frames/part_1.mp4: 384x640 6 persons, 101.2ms
# ...
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
#  obb: None
#  orig_img: array([[[239, 230, 227],
#          [240, 231, 228],
#          [243, 234, 231],
#          ...,
#          [ 73,  63,  65],
#          [ 84,  74,  76],
#          [ 87,  77,  79]],
#
#         [[229, 220, 217],
#          [233, 224, 221],
#          [239, 230, 227],
#          ...,
#          [103,  93,  95],
#          [ 81,  71,  73],
#          [ 68,  58,  60]],
#
#         [[230, 221, 218],
#          [236, 227, 224],
#          [244, 235, 232],
#          ...,
#          [174, 164, 164],
#          [119, 109, 109],
#          [ 88,  78,  78]],
#
#         ...,
#
#         [[126, 157, 141],
#          [124, 155, 139],
#          [124, 155, 139],
#          ...,
#          [118, 157, 135],
#          [117, 156, 134],
#          [117, 156, 134]],
#
#         [[128, 159, 143],
#          [128, 159, 143],
#          [128, 159, 143],
#          ...,
#          [109, 148, 126],
#          [107, 146, 124],
#          [106, 145, 123]],
#
#         [[129, 160, 144],
#          [129, 160, 144],
#          [129, 160, 144],
#          ...,
#          [111, 150, 128],
#          [109, 148, 126],
#          [109, 148, 126]]], dtype=uint8)
#  orig_shape: (720, 1280)
#  path: '/home/mg/projects/deepdaiv/skeleton/audrn/output_frames/part_1.mp4'
#  probs: None
#  save_dir: 'runs/detect/track'
#  speed: {'preprocess': 2.5801658630371094, 'inference': 123.84438514709473, 'postprocess': 1.2423992156982422},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
#  obb: None
#  orig_img: array([[[235, 226, 223],
#          [242, 233, 230],
#          [242, 233, 230],
#          ...,
#          [ 68,  58,  60],
#          [ 79,  69,  71],
#          [ 80,  70,  72]],
#
#         [[231, 222, 219],
#          [242, 233, 230],
#          [244, 235, 232],
#          ...,
#          [ 95,  85,  87],
#          [ 75,  65,  67],
#          [ 74,  64,  66]],
#
#         [[237, 228, 225],
#          [245, 236, 233],
#          [249, 240, 237],
#          ...,
#          [154, 144, 144],
#          [104,  94,  94],
#          [ 91,  81,  81]],
#
#         ...,
#
#         [[122, 153, 137],
#          [119, 150, 134],
#          [110, 141, 125],
#          ...,
#          [111, 150, 128],
#          [109, 148, 126],
#          [110, 149, 127]],
#
#         [[126, 157, 141],
#          [116, 147, 131],
#          [109, 140, 124],
#          ...,
#          [109, 148, 126],
#          [108, 147, 125],
#          [104, 143, 121]],
#
#         [[130, 161, 145],
#          [117, 148, 132],
#          [107, 138, 122],
#          ...,
#          [113, 152, 130],
#          [110, 149, 127],
#          [106, 145, 123]]], dtype=uint8)
#  orig_shape: (720, 1280)
#  path: '/home/mg/projects/deepdaiv/skeleton/audrn/output_frames/part_1.mp4'
#  probs: None
#  save_dir: 'runs/detect/track'
#  speed: {'preprocess': 3.236532211303711, 'inference': 176.21326446533203, 'postprocess': 1.7719268798828125},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
#  obb: None
#  orig_img: array([[[242, 233, 230],
#          [252, 243, 240],
#          [231, 222, 219],
#          ...,
#          [ 70,  62,  64],
#          [ 94,  86,  88],
#          [125, 117, 119]],
#
#         [[242, 233, 230],
#          [252, 243, 240],
#          [231, 222, 219],
#          ...,
#          [ 81,  73,  75],
#          [ 86,  78,  80],
#          [ 82,  74,  76]],
#
#         [[253, 244, 241],
#          [255, 249, 246],
#          [235, 226, 223],
#          ...,
#          [101,  91,  93],
#          [ 83,  73,  75],
#          [ 83,  73,  75]],
#
#         ...,
#
#         [[113, 146, 130],
#          [115, 148, 132],
#          [120, 153, 137],
#          ...,
#          [104, 143, 121],
#          [103, 142, 120],
#          [106, 145, 123]],
#
#         [[110, 143, 127],
#          [117, 150, 134],
#          [122, 155, 139],
#          ...,
#          [103, 142, 120],
#          [102, 141, 119],
#          [108, 147, 125]],
#
#         [[105, 138, 122],
#          [110, 143, 127],
#          [121, 154, 138],
#          ...,
#          [104, 143, 121],
#          [103, 142, 120],
#          [107, 146, 124]]], dtype=uint8)
#  orig_shape: (720, 1280)
#  path: '/home/mg/projects/deepdaiv/skeleton/audrn/output_frames/part_1.mp4'
#  probs: None
#  save_dir: 'runs/detect/track'
#  speed: {'preprocess': 4.638433456420898, 'inference': 166.3498878479004, 'postprocess': 0.9436607360839844},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
#  obb: None
#  orig_img: array([[[244, 235, 232],
#          [239, 230, 227],
#          [212, 203, 200],
#          ...,
#          [ 81,  73,  75],
#          [103,  95,  97],
#          [117, 109, 111]],
#
#         [[251, 242, 239],
#          [243, 234, 231],
#          [215, 206, 203],
#          ...,
#          [ 80,  72,  74],
#          [ 81,  73,  75],
#          [ 75,  67,  69]],
#
#         [[238, 229, 226],
#          [228, 219, 216],
#          [203, 194, 191],
#          ...,
#          [109,  99, 101],
#          [ 88,  78,  80],
#          [ 93,  83,  85]],
#
#         ...,
#
#         [[118, 151, 135],
#          [121, 154, 138],
#          [120, 153, 137],
#          ...,
#          [ 95, 134, 112],
#          [100, 139, 117],
#          [ 99, 138, 116]],
#
#         [[114, 147, 131],
#          [120, 153, 137],
#          [121, 154, 138],
#          ...,
#          [103, 142, 120],
#          [107, 146, 124],
#          [107, 146, 124]],
#
#         [[112, 145, 129],
#          [118, 151, 135],
#          [121, 154, 138],
#          ...,
#          [116, 155, 133],
#          [121, 160, 138],
#          [122, 161, 139]]], dtype=uint8)
#  orig_shape: (720, 1280)
#  path: '/home/mg/projects/deepdaiv/skeleton/audrn/output_frames/part_1.mp4'
#  probs: None
#  save_dir: 'runs/detect/track'
#  speed: {'preprocess': 2.567768096923828, 'inference': 190.6111240386963, 'postprocess': 1.6252994537353516},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
#  obb: None
#  orig_img: array([[[249, 240, 237],
#          [224, 215, 212],
#          [195, 186, 183],
#          ...,
#          [ 89,  79,  81],
#          [108,  98, 100],
#          [122, 112, 114]],
#
#         [[250, 241, 238],
#          [219, 210, 207],
#          [191, 182, 179],
#          ...,
#          [ 93,  83,  85],
#          [ 99,  89,  91],
#          [ 95,  85,  87]],
#
#         [[205, 196, 193],
#          [198, 189, 186],
#          [194, 185, 182],
#          ...,
#          [124, 114, 114],
#          [ 96,  86,  86],
#          [ 93,  83,  83]],
#
#         ...,
#
#         [[117, 150, 134],
#          [114, 147, 131],
#          [117, 150, 134],
#          ...,
#          [ 99, 138, 116],
#          [ 99, 138, 116],
#          [ 99, 138, 116]],
#
#         [[113, 146, 130],
#          [113, 146, 130],
#          [115, 148, 132],
#          ...,
#          [114, 153, 131],
#          [111, 150, 128],
#          [109, 148, 126]],
#
#         [[112, 145, 129],
#          [112, 145, 129],
#          [113, 146, 130],
#          ...,
#          [122, 161, 139],
#          [117, 156, 134],
#          [113, 152, 130]]], dtype=uint8)
#  orig_shape: (720, 1280)
#  path: '/home/mg/projects/deepdaiv/skeleton/audrn/output_frames/part_1.mp4'
#  probs: None
#  save_dir: 'runs/detect/track'
#  speed: {'preprocess': 4.58073616027832, 'inference': 196.5329647064209, 'postprocess': 1.4498233795166016},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
#  obb: None
#  orig_img: array([[[236, 227, 224],
#          [205, 196, 193],
#          [184, 175, 172],
#          ...,
#          [ 86,  76,  76],
#          [101,  91,  91],
#          [110, 100, 100]],
#
#         [[211, 202, 199],
#          [198, 189, 186],
#          [194, 185, 182],
#          ...,
#          [ 81,  71,  71],
#          [ 82,  72,  72],
#          [ 82,  72,  72]],
#
#         [[214, 205, 202],
#          [198, 189, 186],
#          [189, 180, 177],
#          ...,
#          [113, 104, 101],
#          [ 80,  71,  68],
#          [ 74,  65,  62]],
#
#         ...,
#
#         [[118, 151, 135],
#          [118, 151, 135],
#          [118, 151, 135],
#          ...,
#          [111, 150, 128],
#          [113, 152, 130],
#          [114, 153, 131]],
#
#         [[114, 147, 131],
#          [114, 147, 131],
#          [118, 151, 135],
#          ...,
#          [113, 152, 130],
#          [110, 149, 127],
#          [110, 149, 127]],
#
#         [[114, 147, 131],
#          [115, 148, 132],
#          [118, 151, 135],
#          ...,
#          [111, 150, 128],
#          [107, 146, 124],
#          [104, 143, 121]]], dtype=uint8)
#  orig_shape: (720, 1280)
#  path: '/home/mg/projects/deepdaiv/skeleton/audrn/output_frames/part_1.mp4'
#  probs: None
#  save_dir: 'runs/detect/track'
#  speed: {'preprocess': 4.92095947265625, 'inference': 127.90203094482422, 'postprocess': 0.6923675537109375},
#  ...]

# %%
import yaml

# YAML 파일 경로 설정
yaml_file_path = 'labels.yaml'

# YAML 파일 읽기
with open(yaml_file_path, 'r') as file:
    labels = yaml.safe_load(file)

# 클래스 이름 추출
labels['names'][0]
# Out:
# 'person'

# %%
import pytesseract

# %%
def extract_text_from_player(image, box):
    x1, y1, x2, y2 = map(int, box)
    crop_img = image[y1:y2, x1:x2]
    crop_img = cv2.resize(crop_img, None, fx=2, fy=2, interpolation=cv2.INTER_CUBIC)
    gray = cv2.cvtColor(crop_img, cv2.COLOR_BGR2GRAY)
    thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)[1]
    
    # Tesseract로 OCR 적용
    config = r'--oem 3 --psm 6'
    text = pytesseract.image_to_string(thresh, config=config)
    return text.strip()

# %%
# 결과 비디오를 저장할 경로 설정
output_video_path = os.path.join(dir, 'data/preprocessed_video.mp4')

# 입력 비디오를 열어 속성 가져오기
cap = cv2.VideoCapture(video_path)
fps = int(cap.get(cv2.CAP_PROP_FPS))
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

# 출력 비디오 설정
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter(output_video_path, fourcc, fps, (width, height))

# 프레임별로 처리
frame_idx = 0
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break
    
    # 현재 프레임에서 검출된 객체 정보 가져오기
    data = results[frame_idx].boxes  # 현재 프레임의 객체 정보
    
    # 각 객체에 대해 바운딩 박스와 클래스 이름 표시
    #for *xyxy, conf, cls in data:
    for i in range(len(data.xyxy)):
        cls = data.cls[i]
        conf = data.conf[i]
        xyxy = data.xyxy[i]
        label = f'{labels["names"][int(cls)]} {conf:.2f}'
        if int(cls) == 0:   # label is person
            label = f'{extract_text_from_player(frame, xyxy)} {conf:.2f}'
        cv2.rectangle(frame, (int(xyxy[0]), int(xyxy[1])), (int(xyxy[2]), int(xyxy[3])), (0, 255, 0), 2)
        cv2.putText(frame, label, (int(xyxy[0]), int(xyxy[1] - 10)), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
    
    # 수정된 프레임을 결과 비디오에 쓰기
    out.write(frame)
    
    frame_idx += 1

# 모든 자원 해제
cap.release()
out.release()
cv2.destroyAllWindows()

print("Completed annotating video.")
